# %% [markdown]
# # Treinar o modelo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/KAIR-master'
# Out:
# /content/drive/My Drive/KAIR-master

# %% [markdown]
# # Instalação do Ambiente

# %%
# !pip install opencv-python scikit-image pillow torchvision hdf5storage ninja requests timm einops

# %% [markdown]
# # Treinamento

# %%
# !python main_train_psnr.py --opt options/swinir/train_swinir_car_jpeg.json
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (1, 21, 76, 122)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (47, 25, 94, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 59)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 72, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 68)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 86)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 41, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 72, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 125, 113)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 105, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 126, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 77, 82)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ok7
# (0, 0, 110, 126)
# ok1
# ok2
# ok3
# ok4
# ok5
# ok6
# ...

# %%
# !python main_test_swinir.py --task jpeg_car --jpeg 30 --model_path dejpeg/swinir_car_jpeg_30/models/4000_E.pth --folder_gt testsets/classic5
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# loading model from dejpeg/swinir_car_jpeg_30/models/4000_E.pth
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
